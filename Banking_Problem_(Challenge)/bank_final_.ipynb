# %% [markdown]
# ### PROBLEM STATEMENT:
# #### THE DATA IS RELATED TO DIRECT MARKETING CAMPAIGNS OF A PORTUGUESE BANKING INSTITUTION. PREDICT IF THE CLIENT WILL SUBSCRIBE TO A TERM DEPOSIT BASED ON A MARKETING CAMPAIGN

# %% [markdown]
# ### DATA SET INFORMATION:
# #### THE DATA IS RELATED TO DIRECT MARKETING CAMPAIGNS OF A PORTUGUESE BANKING INSTITUTION. TO PREDICT THE PRODUCT (BANK TERM DEPOSIT) WOULD BE ('YES') OR NOT ('NO') SUBSCRIBED.
# ### TARGET :
# #### PREDICT IF THE CLIENT WILL SUBSCRIBE (YES/NO) A TERM DEPOSIT (VARIABLE Y).

# %% [markdown]
# ## Importing the Libararies

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('bank-additional-full.csv', sep = ';')

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
## y = pd.get_dummies(bank['y'], columns = ['y'], drop_first = True)

# %% [markdown]
# ## Seperating different datatypes numerical and categorical / objects

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
numerical = df.select_dtypes(include = np.number)
nonnumerical = df.select_dtypes(exclude = np.number)

# %% [markdown]
# ## Checking categorical columns

# %%
nonnumerical.columns
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'day_of_week', 'poutcome', 'y'],
#       dtype='object')

# %% [markdown]
# # Visualisations:

# %% [markdown]
# ## Univariate analysis of categorical columns

# %%
df["y"].value_counts(normalize=True).plot.bar()
plt.show()

# %%
df["job"].value_counts(normalize=True).plot.bar()
plt.show()

# %%
df["marital"].value_counts(normalize=True).plot.bar()
plt.show()

# %%
df["education"].value_counts(normalize=True).plot.bar()
plt.show()

# %%
df["default"].value_counts(normalize=True).plot.bar()
plt.show()

# %%
df["loan"].value_counts(normalize=True).plot.bar()
plt.show()

# %%
df["contact"].value_counts(normalize=True).plot.bar()
plt.show()

# %%
df["month"].value_counts(normalize=True).plot.bar()
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
sns.countplot(x='marital', hue='y', data=df_upsampled)

# %%
sns.countplot(x='loan', hue='y', data=df_upsampled)

# %%
sns.countplot(x='month', hue='y', data=df_upsampled)

# %%
sns.countplot(x='default', hue='y', data=cleaned_df_copy)

# %%
sns.countplot(x='day_of_week', hue='y', data=df_upsampled)

# %%
sns.countplot(x='poutcome', hue='y', data=df_upsampled)

# %% [markdown]
# ## Students should inculcate fmore saving habits

# %%
nonnumerical["job"].value_counts(normalize=True).plot.bar()


nonnumerical["marital"].value_counts(normalize=True).plot.bar()

# %% [markdown]
# ## Working with nonnumerical data , LabelEncoding the values

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

nonnumerical1 = nonnumerical.copy(deep=True)

# %% [markdown]
# ## LabelEncoding

# %%
for x in list(nonnumerical.iloc[:,:]):
    nonnumerical[x] = le.fit_transform(nonnumerical[x])

# %% [markdown]
# ## Encoded categoricals

# %%
nonnumerical
# Out:
#        job  marital  education  default  housing  loan  contact  month  \
# 0        3        1          0        0        0     0        1      6
# 1        7        1          3        1        0     0        1      6
# 2        7        1          3        0        2     0        1      6
# 3        0        1          1        0        0     0        1      6
# 4        7        1          3        0        0     2        1      6
# 5        7        1          2        1        0     0        1      6
# 6        0        1          5        0        0     0        1      6
# 7        1        1          7        1        0     0        1      6
# 8        9        2          5        0        2     0        1      6
# 9        7        2          3        0        2     0        1      6
# 10       1        1          7        1        0     0        1      6
# 11       7        2          3        0        2     0        1      6
# ...

# %% [markdown]
# ## Classifying age in to multiple bins or segments , to simplify a lot of values

# %%
def age(df):
    df.loc[df['age'] <= 32, 'age'] = 1
    df.loc[(df['age'] > 32) & (df['age'] <= 47), 'age'] = 2
    df.loc[(df['age'] > 47) & (df['age'] <= 70), 'age'] = 3
    df.loc[(df['age'] > 70) & (df['age'] <= 98), 'age'] = 4
           
    return df

# %%
age(numerical)
# Out:
#        age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0        3       261         1    999         0           1.1          93.994
# 1        3       149         1    999         0           1.1          93.994
# 2        2       226         1    999         0           1.1          93.994
# 3        2       151         1    999         0           1.1          93.994
# 4        3       307         1    999         0           1.1          93.994
# 5        2       198         1    999         0           1.1          93.994
# 6        3       139         1    999         0           1.1          93.994
# 7        2       217         1    999         0           1.1          93.994
# 8        1       380         1    999         0           1.1          93.994
# 9        1        50         1    999         0           1.1          93.994
# 10       2        55         1    999         0           1.1          93.994
# ...

# %%
numerical
# Out:
#        age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0        3       261         1    999         0           1.1          93.994
# 1        3       149         1    999         0           1.1          93.994
# 2        2       226         1    999         0           1.1          93.994
# 3        2       151         1    999         0           1.1          93.994
# 4        3       307         1    999         0           1.1          93.994
# 5        2       198         1    999         0           1.1          93.994
# 6        3       139         1    999         0           1.1          93.994
# 7        2       217         1    999         0           1.1          93.994
# 8        1       380         1    999         0           1.1          93.994
# 9        1        50         1    999         0           1.1          93.994
# 10       2        55         1    999         0           1.1          93.994
# ...

# %%
numerical.duration.value_counts().plot('line')

# %% [markdown]
# ## Similarly classiifying duration into multiple bins to simplify

# %%
def duration(df):

    df.loc[df['duration'] <= 102, 'duration'] = 1
    df.loc[(df['duration'] > 102) & (df['duration'] <= 180)  , 'duration']    = 2
    df.loc[(df['duration'] > 180) & (df['duration'] <= 319)  , 'duration']   = 3
    df.loc[(df['duration'] > 319) & (df['duration'] <= 644.5), 'duration'] = 4
    df.loc[df['duration']  > 644.5, 'duration'] = 5

    return df

# %%
duration(numerical)
# Out:
#        age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0        3         3         1    999         0           1.1          93.994
# 1        3         2         1    999         0           1.1          93.994
# 2        2         3         1    999         0           1.1          93.994
# 3        2         2         1    999         0           1.1          93.994
# 4        3         3         1    999         0           1.1          93.994
# 5        2         3         1    999         0           1.1          93.994
# 6        3         2         1    999         0           1.1          93.994
# 7        2         3         1    999         0           1.1          93.994
# 8        1         4         1    999         0           1.1          93.994
# 9        1         1         1    999         0           1.1          93.994
# 10       2         1         1    999         0           1.1          93.994
# ...

# %%
# ## Social and economic context attributes
# Emp.var.rate: employment variation rate - quarterly indicator (numeric)
# Cons.price.idx: consumer price index - monthly indicator (numeric)
# Cons.conf.idx: consumer confidence index - monthly indicator (numeric)
# Euribor3m: euribor 3 month rate - daily indicator (numeric)
# Nr.employed: number of employees - quarterly indicator (numeric)

# %%
nonnumerical.poutcome.value_counts()
# Out:
# 1    35563
# 0     4252
# 2     1373
# Name: poutcome, dtype: int64

# %% [markdown]
# ## Storing numerical column values for reassignment after encoding numerical values

# %%
cols = list(numerical)
cols
# Out:
# ['age',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'emp.var.rate',
#  'cons.price.idx',
#  'cons.conf.idx',
#  'euribor3m',
#  'nr.employed']

# %% [markdown]
# ## RobustScaler scales according to the quantile ranges instead of Maximum

# %%
from sklearn.preprocessing import RobustScaler
scaler = RobustScaler(with_scaling="True")

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.utils import resample

# %%
# column_names = df.columns

# %%
cols
# Out:
# ['age',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'emp.var.rate',
#  'cons.price.idx',
#  'cons.conf.idx',
#  'euribor3m',
#  'nr.employed']

# %% [markdown]
# ## df_r stores the robust scaled data

# %%
df_r = scaler.fit_transform(numerical)

df_r = pd.DataFrame(df_r, columns=cols)

# %%
df_r
# Out:
#        age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0      1.0       0.5      -0.5    0.0       0.0        0.0000        0.266594
# 1      1.0       0.0      -0.5    0.0       0.0        0.0000        0.266594
# 2      0.0       0.5      -0.5    0.0       0.0        0.0000        0.266594
# 3      0.0       0.0      -0.5    0.0       0.0        0.0000        0.266594
# 4      1.0       0.5      -0.5    0.0       0.0        0.0000        0.266594
# 5      0.0       0.5      -0.5    0.0       0.0        0.0000        0.266594
# 6      1.0       0.0      -0.5    0.0       0.0        0.0000        0.266594
# 7      0.0       0.5      -0.5    0.0       0.0        0.0000        0.266594
# 8     -1.0       1.0      -0.5    0.0       0.0        0.0000        0.266594
# 9     -1.0      -0.5      -0.5    0.0       0.0        0.0000        0.266594
# 10     0.0      -0.5      -0.5    0.0       0.0        0.0000        0.266594
# ...

# %% [markdown]
# ## concatenating robustscaled data with label encoded data

# %%
df_treated = pd.concat([df_r, nonnumerical], axis=1)

# %% [markdown]
# # df_treated=df_treated.drop(columns=["y"])

# %% [markdown]
# ## defining target

# %%
y = df.y

# %% [markdown]
# ## df_treated is the final dataframe along with target variable - y

# %%
df_treated = pd.concat([df_treated,y],1)

# %% [markdown]
# ## class imbalance , prediction will likely sway to "no" most times

# %%
df_treated.y.value_counts()
# Out:
# no     36548
# yes     4640
# Name: y, dtype: int64

# %% [markdown]
# ## splitting data by minority and majority values (yes , no)

# %%
df_minority = df_treated[df_treated["y"]=='yes']
df_majority = df_treated[df_treated["y"]=='no']

# %% [markdown]
# ## shapes of both dataframes

# %%
df_majority.shape,df_minority.shape
# Out:
# ((36548, 21), (4640, 21))

# %%
## Resampling is the method that consists of drawing repeated samples from the original data samples 
##uses bootstrapping drawing randomly with replacement from a set of data points 4640 is the minority shape
##hence multiplied by 2

# %%
df_minority_upsampled = resample(df_minority, replace=True,n_samples= int(4640*2), random_state=123)

# %%
df_minority_upsampled
# Out:
#        age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 39152  0.0       0.5       0.5 -995.0       1.0      -0.90625       -0.413493
# 38893  1.0       1.5       0.0    0.0       0.0      -1.40625       -1.196953
# 27708 -1.0       0.0       0.5    0.0       0.0      -0.90625       -0.985854
# 40048  0.0       1.0      -0.5 -986.0       2.0      -0.87500        0.507073
# 28676 -1.0       1.0      -0.5 -994.0       1.0      -0.90625       -0.733406
# 3608  -1.0       1.5      -0.5    0.0       0.0       0.00000        0.266594
# 40194  2.0       1.5      -0.5    0.0       0.0      -0.87500        0.507073
# 40238 -1.0       1.0       0.5 -993.0       2.0      -0.87500        0.507073
# 20438 -1.0       1.0      -0.5    0.0       0.0       0.09375       -0.331882
# 4034   1.0       1.0      -0.5    0.0       0.0       0.00000        0.266594
# 38961  1.0       1.0      -0.5    0.0       0.0      -1.28125       -1.127312
# ...

# %%
## new minority shape

df_minority_upsampled.shape
# Out:
# (9280, 21)

# %%
## concatenating new minority and majority

df_upsampled = pd.concat([df_majority, df_minority_upsampled])

# %%
y_new = df_upsampled["y"]

# %%
y_new
# Out:
# 0         no
# 1         no
# 2         no
# 3         no
# 4         no
# 5         no
# 6         no
# 7         no
# 8         no
# 9         no
# 10        no
# 11        no
# 12        no
# 13        no
# 14        no
# 15        no
# 16        no
# 17        no
# 18        no
# 19        no
# 20        no
# 21        no
# 22        no
# 23        no
# 24        no
# 25        no
# 26        no
# 27        no
# 28        no
# 29        no
#         ...
# 30017    yes
# 24102    yes
# 12264    yes
# 38824    yes
# 8514     yes
# 21043    yes
# 3259     yes
# 29970    yes
# 38324    yes
# 24019    yes
# 13705    yes
# 30000    yes
# 40427    yes
# 1791     yes
# 14382    yes
# 37310    yes
# 20742    yes
# 38640    yes
# 36457    yes
# 40478    yes
# 35182    yes
# 39691    yes
# 39554    yes
# 34136    yes
# 40365    yes
# 39588    yes
# 31944    yes
# 36585    yes
# 31165    yes
# 5850     yes
# Name: y, Length: 45828, dtype: object

# %% [markdown]
# ## train test split on upsampled dataset
# ## using kfold cross val here (10 fold)

# %%
X_train, X_test, y_train, y_test = train_test_split(df_upsampled.drop('y', axis = 1), y_new, test_size = 0.2, random_state = 42)
k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

# %% [markdown]
# ## Random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators = 200, n_jobs=2, random_state = 12)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

# %% [markdown]
# ## cross validating(k/10 folds) with rfc and obtaining the mean subsequently

# %%
cross_val_score(rfc, X_train, y_train, cv=k_fold, n_jobs=2, scoring = 'accuracy')
# Out:
# array([0.94027816, 0.93946005, 0.93780687, 0.93671577, 0.94380797,
#        0.93344244, 0.933988  , 0.94053464, 0.94408074, 0.93507911])

# %%
rfc_cv = (cross_val_score(rfc, X_train, y_train, cv=k_fold, n_jobs=2, scoring = 'accuracy').mean())

# %%
rfc_cv
# Out:
# 0.9385193742988103

# %% [markdown]
# ## checking the precision recall and f1

# %%
from sklearn.metrics import confusion_matrix, classification_report

print(classification_report(y_test, y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.98      0.95      0.96      7342
#          yes       0.81      0.92      0.86      1824
#
#    micro avg       0.94      0.94      0.94      9166
#    macro avg       0.89      0.93      0.91      9166
# weighted avg       0.95      0.94      0.94      9166
#
# 0.9409775256382282

# %% [markdown]
# ## f1 being the harmonic mean of PR is the preferred metric

# %%
from sklearn.metrics import f1_score

# %%
f1_score(pd.get_dummies(y_test,drop_first=True),pd.get_dummies(y_pred,drop_first=True))
# Out:
# 0.8609611924955024

# %% [markdown]
# ## decision tree classifier as a model for consistency

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier(class_weight="balanced")
dtc.fit(X_train, y_train)
y_pred_dtc = dtc.predict(X_test)
accuracy_score(y_test, y_pred_dtc)
# Out:
# 0.9313768274056295

# %%
dtc_cv = (cross_val_score(dtc, X_train, y_train, cv=k_fold, n_jobs=2, scoring = 'accuracy').mean())

dtc_cv

print(classification_report(y_test, y_pred_dtc))
print(accuracy_score(y_test, y_pred_dtc))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.98      0.94      0.96      7342
#          yes       0.78      0.91      0.84      1824
#
#    micro avg       0.93      0.93      0.93      9166
#    macro avg       0.88      0.92      0.90      9166
# weighted avg       0.94      0.93      0.93      9166
#
# 0.9313768274056295

# %%
f1_score(pd.get_dummies(y_test,drop_first=True),pd.get_dummies(y_pred,drop_first=True))

fpr, tpr, thresholds = metrics.roc_curve(pd.get_dummies(y_test,drop_first=True), pd.get_dummies(y_pred_dtc,drop_first=True), pos_label=1)
metrics.auc(fpr, tpr)
# Out:
# 0.9246128678069458

# %%
coef = pd.Series(dtc.feature_importances_,df_upsampled.drop('y', axis = 1).columns).sort_values(ascending=False)
coef.plot(kind='bar', title='Feature Importances')

# %% [markdown]
# ## GridSearchCV doesnt make a difference in terms of estimators

# %%
from sklearn.model_selection import GridSearchCV

rfc_g = RandomForestClassifier(class_weight='balanced')
params= {"n_estimators":np.arange(100,200,15)}

rfc_grid_cv= GridSearchCV(rfc,params,cv=k_fold,n_jobs=2)
rfc_grid_cv.fit(X_train,y_train)
rfc_grid_cv.best_score_
# Out:
# 0.9388194861164149

# %%
rfc_grid_cv.best_params_
# Out:
# {'n_estimators': 175}

# %% [markdown]
# ## But using class weight = balanced makes sure it makes better predictions

# %%
## The "balanced" mode uses the values of y to automatically adjust
## weights inversely proportional to class frequencies in the input data

from sklearn.ensemble import RandomForestClassifier
rfc1 = RandomForestClassifier(n_estimators = 200, n_jobs=2, random_state = 12,class_weight='balanced')
rfc1.fit(X_train, y_train)
y_pred1 = rfc.predict(X_test)

rfc_cv1 = (cross_val_score(rfc1, X_train, y_train, cv=k_fold, n_jobs=2, scoring = 'accuracy').mean())

rfc_cv1
# Out:
# 0.9397196222750767

# %%
## area under the curve is very close to 1 , which ensures 
from sklearn import metrics
fpr, tpr, thresholds = metrics.roc_curve(pd.get_dummies(y_test,drop_first=True), pd.get_dummies(y_pred,drop_first=True), pos_label=1)
metrics.auc(fpr, tpr)
# Out:
# 0.9324599785182105

# %%
## plotting auc roc , auc is almost a square(that is area:1) , desirable 
import matplotlib.pyplot as plt
roc_auc=metrics.auc(fpr, tpr)
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
print(classification_report(y_test, y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.98      0.95      0.96      7342
#          yes       0.81      0.92      0.86      1824
#
#    micro avg       0.94      0.94      0.94      9166
#    macro avg       0.89      0.93      0.91      9166
# weighted avg       0.95      0.94      0.94      9166
#
# 0.9409775256382282

# %%
f1_score(pd.get_dummies(y_test,drop_first=True),pd.get_dummies(y_pred,drop_first=True))
# Out:
# 0.8609611924955024

# %%
from sklearn import metrics
fpr, tpr, thresholds = metrics.roc_curve(pd.get_dummies(y_test,drop_first=True), pd.get_dummies(y_pred,drop_first=True), pos_label=1)
metrics.auc(fpr, tpr)
# Out:
# 0.9324599785182105

# %%
df_upsampled.drop('y', axis = 1).columns
# Out:
# Index(['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',
#        'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed', 'job',
#        'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'day_of_week', 'poutcome'],
#       dtype='object')

# %% [markdown]
# ## deriving importances of features from rfc

# %%
feature_importances = pd.DataFrame(rfc.feature_importances_,index = X_train.columns,columns=['importance']).sort_values('importance',ascending=False)

# %%
## top 10 features 

feature_importances.iloc[:10,:]
# Out:
#               importance
# duration        0.248248
# euribor3m       0.143049
# job             0.063773
# nr.employed     0.061748
# education       0.056924
# campaign        0.055086
# day_of_week     0.049338
# age             0.036901
# emp.var.rate    0.036215
# pdays           0.031717

# %%
top_list=("duration",
"euribor3m",
"job",
"nr.employed",
"education",
"campaign",
"day_of_week",
"age",
"emp.var.rate",
"pdays",
"cons.conf.idx",
"marital",
"poutcome",
"cons.price.idx",
"housing")

# %% [markdown]
# ## Feature Importances and building model on the same

# %%
coef = pd.Series(rfc.feature_importances_,df_upsampled.drop('y', axis = 1).columns).sort_values(ascending=False)
coef.plot(kind='bar', title='Feature Importances')

# %%
## train test split on upsampled dataset with top 10 features

X_train, X_test, y_train, y_test = train_test_split(df_upsampled[["duration","euribor3m","job","nr.employed","education",
"campaign","day_of_week","age","emp.var.rate","pdays","cons.conf.idx","marital","poutcome","cons.price.idx",
"housing"]], y_new, test_size = 0.2, random_state = 42)
k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

## random forest classifier

from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators = 200, n_jobs=2, random_state = 12,class_weight="balanced")
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)
rfc_cv_t10 = (cross_val_score(rfc, X_train, y_train, cv=k_fold, n_jobs=2, scoring = 'accuracy').mean())

rfc_cv_t10
# Out:
# 0.937482978410979

# %%
## the cross val score is not affected by the selection or rather removal of features considered less important

# %%
##--------------------------checked the results with logistic regression to ensure that the model works well all over 
## (it does)

# %%
X_train, X_test, y_train, y_test = train_test_split(df_upsampled.drop('y', axis = 1), y_new, test_size = 0.2, random_state = 42)
k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

from sklearn.linear_model import LogisticRegression
log_reg=LogisticRegression()
log_reg.fit(X_train, y_train)
y_pred_log = log_reg.predict(X_test)

log_reg_cv = (cross_val_score(log_reg, X_train, y_train, cv=k_fold, n_jobs=2, scoring = 'accuracy').mean())

log_reg_cv
# Out:
# 0.8693468797881936

# %%
from sklearn.metrics import confusion_matrix, classification_report

print(classification_report(y_test, y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.98      0.95      0.96      7342
#          yes       0.81      0.92      0.86      1824
#
#    micro avg       0.94      0.94      0.94      9166
#    macro avg       0.89      0.93      0.91      9166
# weighted avg       0.95      0.94      0.94      9166
#
# 0.9409775256382282

# %%
f1_score(pd.get_dummies(y_test,drop_first=True),pd.get_dummies(y_pred,drop_first=True))
# Out:
# 0.8609611924955024

# %%
from sklearn import metrics
fpr, tpr, thresholds = metrics.roc_curve(pd.get_dummies(y_test,drop_first=True), pd.get_dummies(y_pred,drop_first=True), pos_label=1)
metrics.auc(fpr, tpr)
# Out:
# 0.9324599785182105

# %% [markdown]
# ## Using Slices and Voting Classifiers

# %%
## slicing with equal parts
df_slice_final1=pd.concat([df_majority.iloc[0:4000],df_minority])
df_slice_final2=pd.concat([df_majority.iloc[4000:8000],df_minority])
df_slice_final3=pd.concat([df_majority.iloc[8000:12000],df_minority])
df_slice_final4=pd.concat([df_majority.iloc[12000:16000],df_minority])
df_slice_final5=pd.concat([df_majority.iloc[16000:20000],df_minority])
df_slice_final6=pd.concat([df_majority.iloc[20000:24000],df_minority])
df_slice_final7=pd.concat([df_majority.iloc[24000:28000],df_minority])
df_slice_final8=pd.concat([df_majority.iloc[28000:32000],df_minority])
df_slice_final9=pd.concat([df_majority.iloc[32000:36548],df_minority])


from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.neighbors import KNeighborsClassifier
X_train, X_test, y_train, y_test = train_test_split(df_slice_final2.drop(['y'], axis = 1), df_slice_final2["y"], test_size = 0.3, random_state = 42)
clf1 = LogisticRegression(solver='lbfgs', multi_class='multinomial',random_state=42)
clf2 = RandomForestClassifier(n_estimators=200, random_state=123,class_weight="balanced")
clf3 = KNeighborsClassifier()

eclf1 = VotingClassifier(estimators=[('lr', clf1), ('rf', clf2), ('knn', clf3)], voting='hard')
eclf1 = eclf1.fit(X_train, y_train)
y_pred1= eclf1.predict(X_test)

print(classification_report(y_test, y_pred1))
print(accuracy_score(y_test, y_pred1))
f1_score(pd.get_dummies(y_test,drop_first=True),pd.get_dummies(y_pred1,drop_first=True))

eclf2 = VotingClassifier(estimators=[ ('lr', clf1), ('rf', clf2), ('knn', clf3)], voting='soft')
eclf2 = eclf2.fit(X_train, y_train)
y_pred2=eclf2.predict(X_test)

print(classification_report(y_test, y_pred2))
print(accuracy_score(y_test, y_pred2))
f1_score(pd.get_dummies(y_test,drop_first=True),pd.get_dummies(y_pred2,drop_first=True))

eclf3 = VotingClassifier(estimators=[ ('lr', clf1), ('rf', clf2), ('knn', clf3)], voting='soft', weights=[2,1,1], flatten_transform=True)
eclf3 = eclf3.fit(X_train, y_train)
y_pred3=eclf3.predict(X_test)

print(classification_report(y_test, y_pred3))
print(accuracy_score(y_test, y_pred3))
f1_score(pd.get_dummies(y_test,drop_first=True),pd.get_dummies(y_pred3,drop_first=True))
# Out:
#               precision    recall  f1-score   support
#
#           no       0.96      0.97      0.97      1211
#          yes       0.98      0.96      0.97      1381
#
#    micro avg       0.97      0.97      0.97      2592
#    macro avg       0.97      0.97      0.97      2592
# weighted avg       0.97      0.97      0.97      2592
#
# 0.9675925925925926
#               precision    recall  f1-score   support
#
#           no       0.95      0.98      0.97      1211
#          yes       0.99      0.95      0.97      1381
#
#    micro avg       0.97      0.97      0.97      2592
#    macro avg       0.97      0.97      0.97      2592
# weighted avg       0.97      0.97      0.97      2592
#
# 0.9683641975308642
#               precision    recall  f1-score   support
#
#           no       0.95      0.98      0.97      1211
#          yes       0.98      0.96      0.97      1381
#
#    micro avg       0.97      0.97      0.97      2592
# ...

# %% [markdown]
# ### The model below uses upsampled data as a whole , the model above uses slices

# %%
from sklearn.metrics import confusion_matrix, classification_report,f1_score

print(classification_report(y_test, y_pred3))
print(accuracy_score(y_test, y_pred3))
f1_score(pd.get_dummies(y_test,drop_first=True),pd.get_dummies(y_pred3,drop_first=True))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82     11021
#            1       0.82      0.82      0.82     10908
#
#    micro avg       0.82      0.82      0.82     21929
#    macro avg       0.82      0.82      0.82     21929
# weighted avg       0.82      0.82      0.82     21929
#
# 0.8223357198230653
# 0.8218727139722021

# %%
print(classification_report(y_test, y_pred1))
print(accuracy_score(y_test, y_pred1))
f1_score(pd.get_dummies(y_test,drop_first=True),pd.get_dummies(y_pred1,drop_first=True))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.78      0.82     11021
#            1       0.80      0.87      0.83     10908
#
#    micro avg       0.83      0.83      0.83     21929
#    macro avg       0.83      0.83      0.83     21929
# weighted avg       0.83      0.83      0.83     21929
#
# 0.8268958912855123
# 0.8335233751425314

# %%
print(classification_report(y_test, y_pred2))
print(accuracy_score(y_test, y_pred2))
f1_score(pd.get_dummies(y_test,drop_first=True),pd.get_dummies(y_pred2,drop_first=True))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83     11021
#            1       0.81      0.86      0.84     10908
#
#    micro avg       0.83      0.83      0.83     21929
#    macro avg       0.83      0.83      0.83     21929
# weighted avg       0.83      0.83      0.83     21929
#
# 0.8325961056135711
# 0.8360941197481806

# %%
model1 = (cross_val_score(eclf1, X_train, y_train, cv=5, n_jobs=2, scoring = 'accuracy'))
print(model1)
# Out:
# [0.81737346 0.82177057 0.82077592 0.82175315 0.82263266]

# %%
model2 = (cross_val_score(eclf2, X_train, y_train, cv=5, n_jobs=2, scoring = 'accuracy'))
print(model2)
# Out:
# [0.82460426 0.83017393 0.82771426 0.83015733 0.82859377]

# %%
model3 = (cross_val_score(eclf3, X_train, y_train, cv=5, n_jobs=2, scoring = 'accuracy'))
print(model3)
# Out:
# [0.80926324 0.81756889 0.81618294 0.81657383 0.81540115]

# %%
from sklearn import metrics


fpr, tpr, thresholds = metrics.roc_curve(pd.get_dummies(y_test,drop_first=True), pd.get_dummies(y_pred1,drop_first=True), pos_label=1)
metrics.auc(fpr, tpr)
# Out:
# 0.9679608416931208

# %%
import matplotlib.pyplot as plt
roc_auc=metrics.auc(fpr, tpr)
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
print(f1_score(pd.get_dummies(y_test,drop_first=True),pd.get_dummies(y_pred1,drop_first=True)))
# Out:
# 0.9693654266958425
